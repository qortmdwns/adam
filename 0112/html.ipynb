# %%
import requests

response = requests.get("https://shopping.naver.com/home")

# %%
html = response.text
print(html)
# Out:
# <!DOCTYPE html><html lang="ko"><head><meta charSet="utf-8"/><meta name="viewport" content="width=device-width, initial-scale=1, minimum-scale=1.0, maximum-scale=1.0, user-scalable=no, viewport-fit=cover"/><title>네이버쇼핑</title><meta property="og:title" content="네이버쇼핑"/><meta property="og:image" content="https://shopv.pstatic.net/web/cnsv/m/im/ogtag/01_nshopping.png"/><meta property="og:description" content="온/오프라인 상품 탐색과 쇼핑정보, 가격비교, 제품리뷰 등을 만나보세요"/><meta property="description" content="온/오프라인 상품 탐색과 쇼핑정보, 가격비교, 제품리뷰 등을 만나보세요"/><meta property="og:locale" content="ko_KR"/><meta property="og:type" content="website"/><link rel="shortcut icon" href="https://shopv.pstatic.net/web/r/20240115131448/_next/static/ico/favicon_shopping.ico"/><link rel="apple-touch-icon-precomposed" href="https://shopv.pstatic.net/web/r/20240115131448/_next/static/ico/favicon_shopping.ico"/><meta name="apple-mobile-web-app-title" content="네이버쇼핑"/><meta name="application-name" content="네이버쇼핑"/><link rel="stylesheet"
# ...

# %%
#%pip install bs4
from bs4 import BeautifulSoup
soup = BeautifulSoup(html, 'html.parser')

# %%
soup.select_one('div')
# Out:
# <div id="FIRST_LAYER_ID"></div>

# %%
soup.select_one('.home')
# Out:
# <div class="home"><div style="display:none"><div class="pcHeader_header__eETRe"><div class="header_fix"><div class="_gnb_gnb_2C24o" id="gnb-gnb"><div class="_gnb_skip_navigation_3S3aO" id="u_skip"><button class="_gnb_link_3K4IH"><span class="_gnb_text_3gc0U">메인 메뉴로 바로가기</span></button><button class="_gnb_link_3K4IH" data-id="content" data-vertical="HOME"><span class="_gnb_text_3gc0U">본문으로 바로가기</span></button></div><div class="_gnb_header_area_150KE"><div class="header_fix"><div class="_gnbHeader_gnb_header_aiw0M"><div class="_gnbHeader_header_inner_2hQhW"><div class="_gnbHeader_main_site_2NLsV"><a class="_gnbHeader_link_wW48B N=a:GNB.naver" href="https://www.naver.com" title="나의 경쟁력, 네이버"><svg class="_gnbHeader_icon_naver_2Akrc" fill="none" height="13" viewbox="0 0 48 13" width="48"><g clip-rule="evenodd" fill="#fff" fill-rule="evenodd" filter="url(#TextNaver48x13White_svg__vxvlo35tza)"><path d="M14.663 2.5l-3.31 7.957h2.813l.4-1.053h3.173l.4 1.053h2.814L17.643 2.5h-2.98zm1.49 2.507l
# ...

# %%
soup.select_one('.blind')
# Out:
# <span class="blind" lang="en">NAVER</span>

# %%
soup.select_one('#FIRST_LAYER_ID')
# Out:
# <div id="FIRST_LAYER_ID"></div>

# %%
soup.select_one('div > .blind')
# Out:
# <h2 class="blind">검색영역</h2>

# %%
soup.select_one('div .blind')
# Out:
# <span class="blind" lang="en">NAVER</span>

# %%
soup.select(".shoppingCategoryListResponsive_text__rBAL0")[6]
# Out:
# <div class="shoppingCategoryListResponsive_text__rBAL0">멤버십특가</div>

# %%
soup.select_one(".shoppingCategoryListResponsive_link__4rP6J")
# Out:
# <a class="N=a:scut.avgt shoppingCategoryListResponsive_link__4rP6J" href="https://m.shopping.naver.com/panel/outlink?tr=nsh&amp;url=https%3A%2F%2Fshopping.naver.com%2Flogistics%2Fhome"><div class="shoppingCategoryListResponsive_image_area__uOErR"><img alt="" class="shoppingCategoryListResponsive_image__KIca9" data-src="https://shop-phinf.pstatic.net/20230714_33/1689319507981GKPVT_PNG/EB8F84ECB0A9EBB3B4EC9EA5.png?type=f305_305" src="https://shop-phinf.pstatic.net/20230714_33/1689319507981GKPVT_PNG/EB8F84ECB0A9EBB3B4EC9EA5.png?type=f305_305" style="height:"/><svg class="shoppingCategoryListResponsive_icon__C9gqC" fill="none" height="54" viewbox="0 0 54 54" width="54"><path clip-rule="evenodd" d="M54 0H0v54h54zM1 27C1 6.2 6.2 1 27 1s26 5.2 26 26-5.2 26-26 26S1 47.8 1 27" fill="currentColor" fill-rule="evenodd"></path><path clip-rule="evenodd" d="M6.907 6.907C3.325 10.489 2 16.593 2 27s1.325 16.511 4.907 20.093C10.489 50.675 16.593 52 27 52s16.511-1.325 20.093-4.907C50.675 43.511 52 37.4
# ...

# %%
soup.select_one(".shoppingCategoryListResponsive_link__4rP6J")['href']
# Out:
# 'https://m.shopping.naver.com/panel/outlink?tr=nsh&url=https%3A%2F%2Fshopping.naver.com%2Flogistics%2Fhome'

# %%
soup.select_one('.productCardResponsive_image_area__ISr2m img')['src']
# Out:
# 'https://shop-phinf.pstatic.net/20240111_8/1704938272715yaSmu_JPEG/2_1.jpg?type=f300'

# %%
soup.select(".shoppingCategoryListResponsive_text__rBAL0")[6].get_text()
# Out:
# '멤버십특가'

# %%
soup.select(".shoppingCategoryListResponsive_text__rBAL0")#[7]#.get_text()
# Out:
# [<div class="shoppingCategoryListResponsive_text__rBAL0">도착보장</div>,
#  <div class="shoppingCategoryListResponsive_text__rBAL0">쇼핑라이브</div>,
#  <div class="shoppingCategoryListResponsive_text__rBAL0">원쁠딜</div>,
#  <div class="shoppingCategoryListResponsive_text__rBAL0">패션타운</div>,
#  <div class="shoppingCategoryListResponsive_text__rBAL0">장보기</div>,
#  <div class="shoppingCategoryListResponsive_text__rBAL0">선물샵</div>,
#  <div class="shoppingCategoryListResponsive_text__rBAL0">멤버십특가</div>,
#  <div class="shoppingCategoryListResponsive_text__rBAL0">럭셔리</div>,
#  <div class="shoppingCategoryListResponsive_text__rBAL0">미스터</div>,
#  <div class="shoppingCategoryListResponsive_text__rBAL0">리빙윈도</div>,
#  <div class="shoppingCategoryListResponsive_text__rBAL0">푸드윈도</div>,
#  <div class="shoppingCategoryListResponsive_text__rBAL0">키즈윈도</div>,
#  <div class="shoppingCategoryListResponsive_text__rBAL0">펫</div>,
#  <div class="shoppingCategoryListResponsive_text__rBAL0">천원샵</div>,
# ...

# %%
# %pip install openpyxl
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import openpyxl as op

# %%
wb = op.Workbook()

ws = wb.create_sheet('codingon')

ws['A1'] = '이름'
ws['B1'] = '영어이름'

ws['A2'] = '김세령'
ws['B2'] = 'sarah'

wb.save('./codingon.xlsx')

# %%
wb = op.Workbook()

ws = wb.active
ws.title = 'Data'

data = [
  ['Name','Age'],
  ['Alice',30],
  ['Bob',25],
  ['Charlie',35]
]

for row in data:
  ws.append(row)

wb.save('append_example.xlsx')

# %%
# %pip install bs4
# Out:
# ...
#
# ...

# %%
import requests
from bs4 import BeautifulSoup
inp_news = input("뉴스")
News = requests.get('https://search.naver.com/search.naver?where=news&ie=utf8&sm=nws_hty&query='+inp_news)
html = News.text
soup = BeautifulSoup(html, 'html.parser')
A = soup.select('.news_tit')[1].text
B = soup.select('.news_tit')[1]['href']
print(A,B)

#for i in range(10) :
  #C = soup.select('.news_tit')[i].text
  #D = soup.select('.news_tit')[i]['href']
  #print(C,D)

#while html != 0 :
  #page = 11
  #News_2 = requests.get('https://search.naver.com/search.naver?where=news&ie=utf8&sm=nws_hty&query='+inp_news+'&sm=tab_pge&start='+str(page)+'&where=web')
  #html = News_2.text
  #soup = BeautifulSoup(html, 'html.parser')
  #for i in range(10) :
   # E = soup.select('.news_tit')[i].text
    #F = soup.select('.news_tit')[i]['href']
    #print(E,F)
 # page += 10
  #if page >= 31 :
   # break
#def next_page() :
 # page = input('페이지') #page == 11 <- 2페이지 +=10 하면 다음 페이지 넘어감 ex) 11+10 = <- 3페이지
  #News_2 = requests.get('https://search.naver.com/search.naver?where=news&ie=utf8&sm=nws_hty&query='+inp_news+'&sm=tab_pge&start='+page+'&where=web')
  #html = News_2.text
  #soup = BeautifulSoup(html, 'html.parser')
  #for i in range(10) :
   # E = soup.select('.news_tit')[i].text
   # F = soup.select('.news_tit')[i]['href']
   # print(E,F)
#next_page()
# Out:
# 2차전지·AI 간다더니 주가만 띄웠다…13건 집중조사 https://www.nocutnews.co.kr/news/6081333

# %%
# %pip install selenium
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install webdriver_manager
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager

chrome_options = Options()
chrome_options.add_experimental_option("detach", True)

service = Service(executable_path=ChromeDriverManager().install())
driver = webdriver.Chrome(service=service, options=chrome_options)

driver.get("https://www.naver.com")
# Out:
# ---------------------------------------------------------------------------
# NoSuchWindowException                     Traceback (most recent call last)
# Cell In[4], line 12
#       9 service = Service(executable_path=ChromeDriverManager().install())
#      10 driver = webdriver.Chrome(service=service, options=chrome_options)
# ---> 12 driver.get("https://www.naver.com")
#
# File c:\Users\82107\anaconda3\Lib\site-packages\selenium\webdriver\remote\webdriver.py:357, in WebDriver.get(self, url)
#     355 def get(self, url: str) -> None:
#     356     """Loads a web page in the current browser session."""
# --> 357     self.execute(Command.GET, {"url": url})
#
# File c:\Users\82107\anaconda3\Lib\site-packages\selenium\webdriver\remote\webdriver.py:348, in WebDriver.execute(self, driver_command, params)
#     346 response = self.command_executor.execute(driver_command, params)
#     347 if response:
# --> 348     self.error_handler.check_response(response)
# ...

# %%
from selenium.webdriver.common.by import By
login = driver.find_element(By.CLASS_NAME, "MyView-module__link_login___HpHMW")
login.click()

# %%
id = driver.find_elements(By.CLASS_NAME, "input_text")[0]
id.click()
id.send_keys("gamechamp00@naver.com")

# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from time import sleep

chrome_options = Options()
chrome_options.add_experimental_option("detach", True)

service = Service(executable_path=ChromeDriverManager().install())
driver = webdriver.Chrome(service=service, options=chrome_options)

driver.get("https://shopping.naver.com/home")

current_hi = driver.execute_script("return window.scrollr")

while True:
  driver.find_elements(By.CSS_SLECTOR,'body').send_keys(Keys.END)
  sleep(1)

  scrolled_hi = driver.execute_script("return window.scrollr")

  if(current_hi  == scrolled_hi):
    break

  current_ni = scrolled_hi

products = driver.find_elements(By.CSS_SLECTOR, "product_list_item_b84TO")

for product in products:
  title = product.find_elements(By.CSS_SLECTOR,".product_info_tit+cS+pd")
  print(f"제목 {title}")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 20
#      17 current_hi = driver.execute_script("return window.scrollr")
#      19 while True:
# ---> 20   driver.find_elements(By.CSS_SLECTOR,'body').send_keys(Keys.END)
#      21   sleep(1)
#      23   scrolled_hi = driver.execute_script("return window.scrollr")
#
# AttributeError: type object 'By' has no attribute 'CSS_SLECTOR'
