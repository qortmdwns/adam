# %%
import pandas as pd
Book_Read = pd.read_excel("종이책_독서율__성인__20240116155143.xlsx")
print(Book_Read)
print("="*50)
A = Book_Read.loc[:1]
A.head()
# Out:
#     통계분류(1)       통계분류(2)  2021 2021.1 2021.2
# 0   통계분류(1)       통계분류(2)   사례수     읽음    안읽음
# 1        전체            소계  6000   40.7   59.3
# 2        성별            남성  2991   40.4   59.6
# 3       NaN            여성  3009   41.1   58.9
# 4       연령별        19~29세  1016   60.3   39.7
# 5       NaN        30~39세   964   56.3   43.7
# 6       NaN        40~49세  1123   44.4   55.6
# 7       NaN        50~59세  1173   33.9   66.1
# 8       NaN        60세 이상  1724   22.7   77.3
# 9       학력별         중졸 이하   900     12     88
# 10      NaN        고졸, 고퇴  2136   29.2   70.8
# 11      NaN         대재 이상  2964   57.7   42.3
# 12    가구소득별      200만원 미만   715   18.9   81.1
# 13      NaN   200~300만원미만   888   28.2   71.8
# 14      NaN   300~400만원미만  1412   39.3   60.7
# 15      NaN  400~500만원 미만  1521     46     54
# 16      NaN      500만원 이상  1464   54.8   45.2
# ==================================================
#    통계분류(1)  통계분류(2)  2021 2021.1 2021.2
# 0  통계분류(1)  통계분류(2)   사례수     읽음    안읽음
# 1       전체       소계  6000   40.7   59.3

# %%
import matplotlib.pyplot as plt
import seaborn as sns
ratio = [40.7, 59.3]
labels = ["Read", "N_ead"]
wedgeprops = {"width":0.8, "edgecolor": "k", "linewidth" : 1}
plt.pie(ratio, labels = labels, shadow=True, autopct="%.1f%%", wedgeprops=wedgeprops)
plt.show()
