# %%
#전체 사례수 성별 분포 # 목차 (전체 소계 사례수 보여주기)
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns
import numpy as np
plt.rcParams['font.family'] ='Malgun Gothic'
plt.rcParams['axes.unicode_minus'] =False #한글 사용
Book_Read = pd.read_excel("#210075_2021년 국민독서실태조사_성인_Table.xlsx",index_col=0)
#print(Book_Read)
#print("="*50)
Total = Book_Read.iloc[:,:3]
Student = Total.iloc[9:12]
Income = Total.iloc[19:24]
Total.head(4)
# Out:
#            Unnamed: 1 Unnamed: 2 Unnamed: 3
# < 응답자 특성 >
# NaN               NaN        사례수          %
# 전체                NaN       6000        100
# 성별                  남       2991       49.8
# NaN                 여       3009       50.2

# %%
#학력별 사례수와 퍼센트
Student.head()
#Unnamed1 : 응답자 특성, Unnamed1 : 사례수, Unnamed1 : 퍼센트
# Out:
#            Unnamed: 1 Unnamed: 2 Unnamed: 3
# < 응답자 특성 >
# 학력               중졸이하        900         15
# NaN             고졸/고퇴       2136       35.6
# NaN              대재이상       2964       49.4

# %%
#학력별 사례수 퍼센트 데이터 시각
import matplotlib.pyplot as plt
import seaborn as sns
ratio = [900, 2136,  2964]
labels = ["중졸이하", "고졸/고퇴", "대재이상"]
wedgeprops = {"width":0.8, "edgecolor": "k", "linewidth" : 1}
plt.pie(ratio, labels = labels, shadow=True, autopct="%.1f%%", wedgeprops=wedgeprops)
plt.show()
print("="*50)
# Out:
# ==================================================

# %%
#평일, 휴일 학력별 (종이,전자,오디오)책 독서 시간(분)
A = Book_Read.iloc[787:790]
Student_Read_Time = A.iloc[:,:8]
Student_Read_Time.head()
#Unnamed1 학력, Unnamed2 사례수, Unnamed3 종이-평일(분), Unnamed4 전자=평일(분), Unnamed5 오디오=평일(분)
#Unnamed6 종이=휴일(분), Unnamed7 전자=휴일(분), Unnamed8 오디오=휴일(분)
# Out:
#            Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# < 응답자 특성 >
# 학력               중졸이하        900          4        0.1          0        2.5
# NaN             고졸/고퇴       2136        9.8        1.9        0.5       10.6
# NaN              대재이상       2964       16.9         12        2.5       23.7
#
#            Unnamed: 7 Unnamed: 8
# < 응답자 특성 >
# 학력                0.1          0
# NaN               2.5        0.5
# NaN                18        2.8

# %%
#학력별 총 독서시간(분) 데이터 시각
Read_Mid = 4.0+0.1+0.0+2.5+0.1+0.0
Read_High = 9.8+1.9+0.5+10.6+2.5+0.5
Read_Uni = 16.9+12.0+2.5+23.7+18.0+2.8
x = np.arange(3)
plt.bar(x,[Read_Mid,Read_High,Read_Uni], color=["r","g","b"],  width=0.6)
plt.xticks(x,["Read_Mid", "Read_High", "Read_Uni"])
plt.grid(True, axis="y")
plt.title("Student_Read_Time",loc="center",pad=20)
plt.show()
#학력과 독서량은 비례한다는 가정 True

# %%
#가구소득별 사례수와 퍼센트
Income.head()
#Unnamed1 : 응답자 특성, Unnamed1 : 사례수, Unnamed1 : 퍼센트
# Out:
#               Unnamed: 1 Unnamed: 2 Unnamed: 3
# < 응답자 특성 >
# 가구소득            200만원 미만        715       11.9
# NaN         200-300만원 미만        888       14.8
# NaN         300-400만원 미만       1412       23.5
# NaN         400-500만원 미만       1521       25.4
# NaN             500만원 이상       1464       24.4

# %%
#가구소득별 사례수 퍼센트 데이터 시각
ratio = [715, 888,  1412, 1521, 1464]
labels = ["200미만", "200-300미만", "300-400미만", "400-500미만", "500이상"]
wedgeprops = {"width":0.8, "edgecolor": "k", "linewidth" : 1}
plt.pie(ratio, labels = labels, shadow=True, autopct="%.1f%%", wedgeprops=wedgeprops)
plt.show()
print("="*50)
# Out:
# ==================================================

# %%
#평일, 휴일 가구소득별 (종이,전자,오디오)책 독서 시간(분)
B = Book_Read.iloc[797:802]
Income_Read_Time = B.iloc[:,:8]
Income_Read_Time.head()
#Unnamed1: 소득, Unnamed2: 사례수, Unnamed3: 종이-평일(분), Unnamed4: 전자-평일(분), Unnamed5: 오디오-평일(분)
#Unnamed6: 종이-휴일(분), Unnamed7: 전자-휴일(분), Unnamed8: 오디오-휴일(분)
# Out:
#               Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# < 응답자 특성 >
# 가구소득            200만원 미만        715        7.1        1.9        0.4
# NaN         200-300만원 미만        888        9.8        2.9        0.3
# NaN         300-400만원 미만       1412       10.7        5.7        0.9
# NaN         400-500만원 미만       1521         14        8.3        1.9
# NaN             500만원 이상       1464       16.6       10.2        2.7
#
#            Unnamed: 6 Unnamed: 7 Unnamed: 8
# < 응답자 특성 >
# 가구소득              5.6        1.8        0.4
# NaN                11          5        0.5
# NaN              14.1       10.1        1.4
# NaN              18.3       12.4        1.3
# NaN              23.1       13.7        3.3

# %%
#가구소득별 총 독서시간(분) 데이터 시각
TwoH_Under = 7.1+1.9+0.4+5.6+1.8+0.4
TwoThreeH_Under = 9.8+2.9+0.3+11.0+5.0+0.5
ThreeFourH_Under = 10.7+5.7+0.9+14.1+10.1+1.4
FourFiveH_Under = 14.0+8.3+1.9+18.3+12.4+1.3
FiveH_Over = 16.6+10.2+2.7+23.1+13.7+3.3
x = np.arange(5)
plt.bar(x,[TwoH_Under,TwoThreeH_Under,ThreeFourH_Under,FourFiveH_Under,FiveH_Over], color=["r","g","b","y","k"],  width=0.4)
plt.xticks(x,["200미만", "200-300미만", "300-400미만", "400-500미만", "500이상"])
plt.grid(True, axis="y")
plt.title("Income_Read_Time",loc="center",pad=20)
plt.show()
#소득과 독서량은 비례한다는 가정 True

# %%
import matplotlib.pyplot as plt #1페이지
import pandas as pd
import seaborn as sns

plt.rcParams['font.family'] ='Malgun Gothic'
plt.rcParams['axes.unicode_minus'] =False #한글 사용


physicla_data=pd.read_csv("2022년 국민생활체육조사_샘플데이터.csv") #샘플 데이터 읽어오기
physicla_table=pd.read_csv("2022년 국민생활체육조사 코드북.csv") 
physicla_var=pd.read_excel("자주_이용하는_세부체육시설_민간체육시설_상위_5개_시설__20240116152454.xlsx",index_col=0) 


new_columns=physicla_table['내용']
physicla_data.columns=new_columns #읽기 쉬운 columns 로 변경

grade=physicla_data['최종학력'] #학력 
income=physicla_data['월평균가구소득 (만원)'] #소득
own_place=physicla_data['자주 이용하는 체육시설 유형'] #체육 시설

# 목차

own_value=own_place.value_counts() #이용 체육시설 값 읽기
wedgeprops={'width':0.8,'edgecolor':'k','linewidth':0.8} #pie 만들기 조건
plt.title('사람들이 이용하는 체육시설들의 비율')
plt.pie(own_value,labels=own_value.index,explode=[0.1,0,0,0,0,0,0],
        autopct='%.1f%%',wedgeprops=wedgeprops,shadow={'ox': -0.04, 'edgecolor': 'none', 'shade': 0.9}) 
#이용 체육시설 중에 민간 체육시설의 퍼센트 확인
# Out:
# c:\Users\test\anaconda3\Lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# ([<matplotlib.patches.Wedge at 0x1b377182b10>,
#   <matplotlib.patches.Wedge at 0x1b377150e10>,
#   <matplotlib.patches.Wedge at 0x1b36f07dfd0>,
#   <matplotlib.patches.Wedge at 0x1b3771a7890>,
#   <matplotlib.patches.Wedge at 0x1b3771f9a10>,
#   <matplotlib.patches.Wedge at 0x1b3771fbcd0>,
#   <matplotlib.patches.Wedge at 0x1b377202150>],
#  [Text(0.5447886197087486, 1.0692078188246832, '민간체육시설'),
#   Text(-1.0978293989430645, 0.06906960848527927, '공공체육시설'),
#   Text(-0.20611945413751406, -1.080515974257694, '기타'),
#   Text(0.6741977818040064, -0.8691704959388334, '기타체육시설'),
#   Text(1.0095301050222132, -0.43686264094545685, '학교체육시설'),
#   Text(1.0913261766736644, -0.13786651553891585, '자가시설'),
#   Text(1.0994572176396824, -0.034551795611921995, '직장체육시설')],
#  [Text(0.31779336149676995, 0.6237045609810652, '35.0%'),
#   Text(-0.598816035787126, 0.03767433190106142, '28.0%'),
#   Text(-0.11242879316591675, -0.5893723495951056, '18.0%'),
#   Text(0.36774424462036703, -0.47409299778481817, '9.0%'),
#   Text(0.5506527845575708, -0.23828871324297643, '7.0%'),
#   Text(0.5952688236401805, -0.07519991756668137, '2.0%'),
#   Text(0.5997039368943722, -0.01884643397013927, '1.0%')])

# %%
A=list(physicla_var.values[1]) # 2-1
A.remove('소계')
B=list(physicla_var.values[0])
B.remove('통계분류(2)')

wedgeprops={'width':0.8,'edgecolor':'k','linewidth':0.8} #pie 만들기 조건
plt.title('민간체육시설들을 이루고 있는 비율')
plt.pie(A,labels=B,autopct='%.1f%%',wedgeprops=wedgeprops,
        shadow={'ox': -0.04, 'edgecolor': 'none', 'shade': 0.9},explode=[0.1,0,0,0,0])
# Out:
# ([<matplotlib.patches.Wedge at 0x1b377242f50>,
#   <matplotlib.patches.Wedge at 0x1b377266910>,
#   <matplotlib.patches.Wedge at 0x1b3772709d0>,
#   <matplotlib.patches.Wedge at 0x1b377272a10>,
#   <matplotlib.patches.Wedge at 0x1b377280ad0>],
#  [Text(0.26531826309091083, 1.1703017641917928, '체력단련장'),
#   Text(-1.099082592673323, -0.04491608267075784, '수영장'),
#   Text(-0.603126794779348, -0.9199119900399115, '골프연습장'),
#   Text(0.33706896953158755, -1.047083812203643, '볼링장'),
#   Text(1.0065178233216119, -0.4437587986011375, '당구장')],
#  [Text(0.1547689868030313, 0.682676029111879, '42.9%'),
#   Text(-0.5994995960036307, -0.024499681456777, '15.5%'),
#   Text(-0.3289782516978262, -0.5017701763854062, '14.7%'),
#   Text(0.18385580156268408, -0.5711366248383507, '13.7%'),
#   Text(0.5490097218117882, -0.2420502537824386, '13.2%')])

# %%
new_df_2=pd.DataFrame([own_place,grade]) # 2-2
grade_val=grade.value_counts() #grade 값 세기
private_user=0
by_grade=grade_val.index # x index로 들어갈 변수 - grade_val 의 index
R=list(0 for _ in by_grade) # 민간 체육 시설 이용자 수를 담아둘 변수

for j in range(5):
  for i in range(100):
    if new_df_2[i][1]==by_grade[j] and new_df_2[i][0]=='민간체육시설': # index 가 같고 민간체육시설을 이용할 때
      R[j]+=1 #count
      private_user=private_user+1

y_result=list(0 for  _ in range(5)) #y결과 도출 (해당 학력 구간 민간체육시설 이용자/민간체육시설 총 이용자)
for u in range(5):
  y_result[u]=(R[u]/private_user) *100
  

plt.title('학력별 민간체육시설 이용률')
plt.ylabel('percent')
sns.barplot(x=by_grade,y=y_result)
# Out:
# <Axes: title={'center': '학력별 민간체육시설 이용률'}, xlabel='최종학력', ylabel='percent'>

# %%
#Total = Book_Read.iloc[:,:3]
#Student = Total.iloc[9:12]
#Income = Total.iloc[19:24]
Sport_condition = pd.read_excel("체육활동_참여_촉진을_위한_선행조건_123순위__20240116150503.xlsx",index_col="통계분류(2)")
G = Sport_condition.iloc[28:37]
H_M_Sport_Condition = G.iloc[:,2:]

H_M_Sport_Condition
# Out:
#               체육활동 가능시간 증가  체육시설 접근성 확대  체육활동 지출비용 여유  건강상태 개선  \
# 통계분류(2)
# 100만원 미만              42.0         37.7          11.5     71.1
# 100-200만원 미만          54.2         45.6          33.0     46.4
# 200-300만원 미만          60.5         46.2          31.9     38.1
# 300-400만원 미만          67.8         45.6          39.0     29.7
# 400-500만원 미만          68.1         45.1          39.1     32.1
# 500-600만원 미만          69.6         49.2          38.4     31.2
# 600-700만원 미만          75.7         47.4          45.1     34.2
# 700-800만원 미만          69.9         52.1          50.4     25.5
# 800-900만원 미만          68.5         45.6          52.7     30.5
#
#               체육활동에 대한 관심 증가  소득수준 증가  동반참여자 확보  체육활동 프로그램 확대  체육활동정보 접근성 확대  \
# 통계분류(2)
# 100만원 미만                54.0     10.2      32.3          13.1           21.5
# 100-200만원 미만            23.9     24.6      31.1          18.0            9.7
# 200-300만원 미만            28.8     17.1      24.7          28.1           11.8
# 300-400만원 미만            26.0     21.7      21.8          22.8           13.1
# 400-500만원 미만            23.7     22.6      22.1          18.5           11.5
# 500-600만원 미만            29.6     23.1      13.7          15.7           15.0
# 600-700만원 미만            23.5     21.0      13.1          15.3           13.9
# 700-800만원 미만            21.6     29.2      13.0          11.7           13.1
# 800-900만원 미만            16.7     24.6      17.0          12.8           17.0
#
#               체육지도자 수준 향상
# 통계분류(2)
# 100만원 미만              0.0
# 100-200만원 미만          7.7
# 200-300만원 미만          7.4
# 300-400만원 미만          7.6
# 400-500만원 미만         11.0
# 500-600만원 미만          9.4
# 600-700만원 미만          6.4
# 700-800만원 미만          5.4
# 800-900만원 미만          9.3

# %%
H_M_Sport_Condition=H_M_Sport_Condition.astype(float)
plt.figure(figsize=(14,7))

plt.title("What you need before starting a workout")

sns.heatmap(data=H_M_Sport_Condition, annot=True)
plt.xticks(rotation=45)
plt.xlabel("what you need")

plt.ylabel("Income")
# Out:
# Text(146.64409722222223, 0.5, 'Income')

# %%
new_df_1=pd.DataFrame([own_place,income]) #2-4
income_val=income.value_counts()
x_by_income=['~200','200~300','300~400','400~500','500~'] # x index
T=list(0 for _ in range(5))

for i in range(100):
  if  new_df_1[i][1]<=200 and new_df_1[i][0]=='민간체육시설': # 해당 금액 범위 내 민간 체육시설 이용객 카운팅
    T[0]+=1
  elif new_df_1[i][1]<=300 and new_df_1[i][0]=='민간체육시설':
    T[1]+=1
  elif new_df_1[i][1]<=400 and new_df_1[i][0]=='민간체육시설':
    T[2]+=1
  elif new_df_1[i][1]<=500 and new_df_1[i][0]=='민간체육시설':
    T[3]+=1
  elif new_df_1[i][0]=='민간체육시설':
    T[4]+=1

y_result=list(0 for  _ in range(5))
for u in range(5):
  y_result[u]=(T[u]/private_user) *100
  
plt.title('소득별 민간체육시설 이용률')  
plt.ylabel('percent')

sns.barplot(x=x_by_income,y=y_result)
# Out:
# <Axes: title={'center': '소득별 민간체육시설 이용률'}, ylabel='percent'>
